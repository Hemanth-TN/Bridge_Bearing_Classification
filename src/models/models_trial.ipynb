# %%
import os
os.getcwd()
# Out:
# 'c:\\Pytorch\\bearing-failure\\src\\models'

# %%
from pathlib import Path


models_dir = Path('../../trained_models')
os.listdir(models_dir)
# Out:
# ['efficientnet_b0_adam.pth',
#  'efficientnet_b1_sgd.pth',
#  'efficientnet_b2_sgd.pth',
#  'efficientnet_b3_adam.pth',
#  'efficientnet_b4_adam.pth']

# %%
import random


random_image
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 4
#       1 import random
# ----> 4 random_image
#
# NameError: name 'random_image' is not defined

# %%
from PIL import Image
import numpy as np
import os

random_image = random.choice(os.listdir('../../data/Test_300x300/2'))
img_array = np.asarray(Image.open(f'../../data/Test_300x300/2/{random_image}'))

# %%
img_array.shape
# Out:
# (300, 300, 3)

# %%
import matplotlib.pyplot as plt

plt.imshow(img_array)

# %%
from torchvision.models import efficientnet_b0, EfficientNet_B0_Weights,\
      efficientnet_b1, EfficientNet_B1_Weights, \
        efficientnet_b2, EfficientNet_B2_Weights, \
            efficientnet_b3, EfficientNet_B3_Weights, \
                efficientnet_b4, EfficientNet_B4_Weights
from torch import nn

# %%
model_b0_transforms = EfficientNet_B0_Weights.DEFAULT.transforms()
model_b0_transforms
# Out:
# ImageClassification(
#     crop_size=[224]
#     resize_size=[256]
#     mean=[0.485, 0.456, 0.406]
#     std=[0.229, 0.224, 0.225]
#     interpolation=InterpolationMode.BICUBIC
# )

# %%
random_image
# Out:
# '302_Bearing.jpeg'

# %%
transformed_image = model_b0_transforms(Image.open(f'../../data/Test_300x300/2/{random_image}'))

# %%
model_b0 = efficientnet_b0()

# %%
transformed_image.shape, transformed_image.unsqueeze(0).shape
# Out:
# (torch.Size([3, 224, 224]), torch.Size([1, 3, 224, 224]))

# %%
pred_logits = model_b0(transformed_image.unsqueeze(0))

# %%
pred_logits.argmax().item()
# Out:
# 976

# %%
import numpy as np
model_preds = [2,5,0,1,2]
np.bincount(model_preds).argmax()
# Out:
# np.int64(2)

# %%
models = [efficientnet_b0(), efficientnet_b1(), efficientnet_b2(), efficientnet_b3(), efficientnet_b4()]

for m in models:
    print(m.classifier)
# Out:
# Sequential(
#   (0): Dropout(p=0.2, inplace=True)
#   (1): Linear(in_features=1280, out_features=1000, bias=True)
# )
# Sequential(
#   (0): Dropout(p=0.2, inplace=True)
#   (1): Linear(in_features=1280, out_features=1000, bias=True)
# )
# Sequential(
#   (0): Dropout(p=0.3, inplace=True)
#   (1): Linear(in_features=1408, out_features=1000, bias=True)
# )
# Sequential(
#   (0): Dropout(p=0.3, inplace=True)
#   (1): Linear(in_features=1536, out_features=1000, bias=True)
# )
# Sequential(
#   (0): Dropout(p=0.4, inplace=True)
#   (1): Linear(in_features=1792, out_features=1000, bias=True)
# )

# %%
import os

# %%
models_dir = '../../trained_models/'

# %%
os.listdir(models_dir)
# Out:
# ['efficientnet_b0_adam.pth',
#  'efficientnet_b1_sgd.pth',
#  'efficientnet_b2_sgd.pth',
#  'efficientnet_b3_adam.pth',
#  'efficientnet_b4_adam.pth']
