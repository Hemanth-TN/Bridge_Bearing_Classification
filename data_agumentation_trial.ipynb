# %%
from pathlib import Path
import torchvision.transforms as transforms
from PIL import Image
import os
import random
from helpers import plot

# %%
img_file
# Out:
# '1249_Bearing.jpeg'

# %%
image_path = Path('data')/'Train_300x300'/'1'
image_files = os.listdir(image_path)
img_file = random.choice(image_files)
img = Image.open(image_path / img_file)
rotation_transform = transforms.Compose([transforms.RandomAutocontrast(p=1)])
transformed_image = rotation_transform(img)
plot([img, transformed_image])

# %%
image_path = Path('data')/'Train_300x300'/'2'
image_files = os.listdir(image_path)
img_file = random.choice(image_files)
img = Image.open(image_path / img_file)
rotation_transform = transforms.Compose([transforms.RandomVerticalFlip(p=1)])
transformed_image = rotation_transform(img)
plot([img, transformed_image])

# %%
image_path = Path('data')/'Train_300x300'/'1'
image_files = os.listdir(image_path)
img_file = random.choice(image_files)
img = Image.open(image_path / img_file)
rotation_transform = transforms.Compose([transforms.ElasticTransform(90.0)])
transformed_image = rotation_transform(img)
plot([img, transformed_image])

# %%
image_path = Path('data')/'Train_300x300'/'1'
image_files = os.listdir(image_path)
img_file = random.choice(image_files)
img = Image.open(image_path / img_file)
rotation_transform = transforms.Compose([transforms.RandomAffine(10)])
transformed_image = rotation_transform(img)
plot([img, transformed_image])

# %%
image_path = Path('data')/'Train_300x300'/'1'
image_files = os.listdir(image_path)
img_file = random.choice(image_files)
img = Image.open(image_path / img_file)
rotation_transform = transforms.Compose([transforms.Resize((300,300))])
transformed_image = rotation_transform(img)
plot([img, transformed_image])

# %%
image_path = Path('data')/'Train_300x300'/'1'
image_files = os.listdir(image_path)
img_file = random.choice(image_files)
img = Image.open(image_path / img_file)
rotation_transform = transforms.Compose([transforms.RandomRotation(15)])
transformed_image = rotation_transform(img)
plot([img, transformed_image])

# %%
image_path = Path('data')/'Train_300x300'/'2'
image_files = os.listdir(image_path)
img_file = random.choice(image_files)
img = Image.open(image_path / img_file)
rotation_transform = transforms.Compose([transforms.RandomHorizontalFlip(p=1)])
transformed_image = rotation_transform(img)
plot([img, transformed_image])

# %%
image_path = Path('data')/'Train_300x300'/'2'
image_files = os.listdir(image_path)
img_file = random.choice(image_files)
img = Image.open(image_path / img_file)
rotation_transform = transforms.Compose([transforms.ColorJitter(brightness=(1.3,1.6), contrast=0.4, saturation=0.3)])
transformed_image = rotation_transform(img)
plot([img, transformed_image])

# %%
image_path = Path('data')/'Train_300x300'/'2'
image_files = os.listdir(image_path)
img_file = random.choice(image_files)
img = Image.open(image_path / img_file)
rotation_transform = transforms.Compose([transforms.RandomPerspective(0.5, p=1)])
transformed_image = rotation_transform(img)
plot([img, transformed_image])

# %%
image_path = Path('data')/'Train_300x300'/'1'
image_files = os.listdir(image_path)
img_file = random.choice(image_files)
img = Image.open(image_path / img_file)
rotation_transform = transforms.Compose([transforms.RandomPosterize(8,p=1)])
transformed_image = rotation_transform(img)
plot([img, transformed_image])

# %%
image_path = Path('data')/'Train_300x300'/'3'
image_files = os.listdir(image_path)
img_file = random.choice(image_files)
img = Image.open(image_path / img_file)
rotation_transform = transforms.Compose([transforms.RandomAutocontrast(p=1)])
transformed_image = rotation_transform(img)
plot([img, transformed_image])

# %%
image_path = Path('data')/'Train_300x300'/'4'
image_files = os.listdir(image_path)
img_file = random.choice(image_files)
img = Image.open(image_path / img_file)
rotation_transform = transforms.Compose([transforms.RandomAffine(degrees=10, translate=(0.3,0.3))])
transformed_image = rotation_transform(img)
plot([img, transformed_image])

# %%
transformed_image.save(f"{img_file}_transformed.png")

# %%
transformed_image.size
# Out:
# (300, 300)

# %%
transformations = {'1': [transforms.Compose([transforms.RandomHorizontalFlip(p=1)]),
                        transforms.Compose([transforms.RandomRotation(15)]),
                        transforms.Compose([transforms.ColorJitter(brightness=(1.3,1.6), contrast=0.4, saturation=0.3)]),
                        transforms.Compose([transforms.RandomPerspective(0.5, p=1)])],
                    '2': [transforms.Compose([transforms.RandomHorizontalFlip(p=1)]),
                            transforms.Compose([transforms.ColorJitter(brightness=(1.3,1.6), contrast=0.4, saturation=0.3)])],
                    '3':[transforms.Compose([transforms.Resize((300,300))])],
                    '4':[transforms.Compose([transforms.RandomHorizontalFlip(p=1)]),
                        transforms.Compose([transforms.RandomRotation(15)]),
                        transforms.Compose([transforms.ColorJitter(brightness=(1.3,1.6), contrast=0.4, saturation=0.3)]),
                        transforms.Compose([transforms.RandomPerspective(0.5, p=1)]),
                        transforms.Compose([transforms.RandomAutocontrast(p=1)])] 
                    }

len(transformations['4'])
# Out:
# 5
